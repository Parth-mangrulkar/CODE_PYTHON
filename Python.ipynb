# %%
print("Hello, World!") 
#the print here is used to print the string "Hello, World!" to the console. 
# The print function is a built-in function in Python that outputs text or other data types to the standard output, 
# which is usually the console or terminal.
# Out:
# Hello world

# %%
print( "Hello, World!", "I AM parth mangrulkar", "I am learning python", sep = "\n")
# Out:
# Hello, World!
# I AM parth mangrulkar
# I am learning python

# %%
print(23+32)
# Out:
# 55

# %%
age = 21
name= "Parth Mangrulkar"
prince=22.3

# %%
age = 23
print(f"My age is {age}")
# Out:
# My age is 23

# %%
print(type(age))
print(type(name))
print(type(prince))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
